# %% [markdown]
# ### 1. Градиентный спуск
#
# В данном разделе предстоит минимизировать функцию $$ f(x, y) = x^2 + y^2 $$ при помощи метода градиентного спуска

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import warnings

warnings.filterwarnings(action='ignore')

# %% [markdown]
# Задание 1. Реализуйте функцию gradient_vector таким образом, чтобы она возвращала градиент заданной функции f(x, y)
#
# должен возвращаться numpy array, содержащий 2 numpy array (производные по x и y)

# %%
def gradient_vector(x: np.array, y: np.array) -> np.array:
    df_dx = 2 * x
    df_dy = 2 * y

    return np.array([df_dx, df_dy])

# %% [markdown]
# Задание 2. Реализуйте обновление координат найденного экстремума методом градиентного спуска.

# %%
def gradient_descent(vector, lr=0.001, epsilon=0.001, stop_iteration=10000):
    """

    Args:
        vector (np.array): исходные занчения аргументво x, y
        lr (float, optional): learning rate. Коэффициент скорости обучения.
        epsilon (float, optional): Допустимая погрешность
        stop_iteration (int, optional): количество итераций

    Returns:
        np.array, содержащий координаты экстремума, номер итерации, градиенты x, y, значения отклонений от истинного значения
    """
    iteration = 1
    x_gradient = np.array([])
    y_gradient = np.array([])
    loss = np.array([])

    extremum = vector

    x_gradient = np.append(x_gradient, extremum[0])
    y_gradient = np.append(y_gradient, extremum[1])

    while True:
        grad = gradient_vector(extremum[0], extremum[1])
        new_extremum = extremum - lr * grad

        loss = np.append(loss, np.linalg.norm(new_extremum - extremum))
        extremum = new_extremum

        x_gradient = np.append(x_gradient, extremum[0])
        y_gradient = np.append(y_gradient, extremum[1])

        iteration += 1
        if np.linalg.norm(grad) < epsilon or iteration == stop_iteration:
            break

    return extremum, iteration, x_gradient, y_gradient, loss

# %%
def plot_contour(x_gradient, y_gradient, vector):
    """
    Визуализация поиска точки экстремума
    """
    figure, ax = plt.subplots(1, 1, figsize=(10, 5))
    sns.set_theme(style='whitegrid', palette='pastel')

    contour = plt.contour(X, Y, Z, cmap=cm.RdBu)
    plt.clabel(contour, fontsize=10)

    ax.text(x=vector[0]+0.05, y=vector[1]-0.25, s='start', c='r')
    plt.plot(vector[0], vector[1], 'ro')

    ax.text(x=x_gradient[-1]+0.05, y=y_gradient[-1]-0.25, s='finish', c='b')
    plt.plot(x_gradient, y_gradient, 'bo')

    plt.show()

# %%
def plot_loss(loss):
    figure, ax = plt.subplots(1, 1, figsize=(10, 5))
    sns.set_theme(style='whitegrid', palette='pastel')

    ax = sns.lineplot(data=loss)
    ax.set(xlabel='Iteration')
    ax.set(ylabel='Value')
    ax.set_title('Losses')

    plt.show()

# %% [markdown]
# Инициализация функции для поиска точки экстремума, генерация значений функции.

# %% [markdown]
# $$   f(x, y) = x^2 + y^2 $$

# %%
def f(x, y):
    return np.power(x, 2) + np.power(y, 2)

x = np.arange(-2, 2, 0.1)
y = np.arange(-2, 2, 0.1)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %% [markdown]
# 3. Воспользуйтесь полученной функцией

# %%
vector = np.array([1.8, 1.8])
extremum, iteration, gdx_gradient, gdy_gradient, loss = gradient_descent(vector)

# %% [markdown]
# Визуализация градиентного спуска

# %%
print('Function extremum reached at point: ({:.5f}, {:.5f}).'.format(extremum[0], extremum[1]))
print('Number of iterations: {}.'.format(iteration))

plot_contour(gdx_gradient, gdy_gradient, vector)
# Out:
# Function extremum reached at point: (0.00035, 0.00035).
# Number of iterations: 4266.

# %% [markdown]
# Визуализация функции потерь

# %%
plot_loss(loss)

# %% [markdown]
# ### 2. Реализация нейронной сети для решения задачи классификации

# %%
# !wget  -O 'WineQT.csv' -q 'https://www.dropbox.com/scl/fi/qsacgxfmrio4d8crvksad/WineQT.csv?rlkey=o8mb42t8mfru5o9llgu98cxn6&dl=0'

# %%
import numpy as np
import pandas as pd

import torch
import torch.nn as nn

from tqdm import tqdm

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('WineQT.csv')

# %% [markdown]
# **Колонки**
#
# - fixed acidity
# - volatile acidity
# - citric acid
# - residual sugar
# - chlorides
# - free sulfur dioxide
# - total sulfur dioxide
# - density
# - pH
# - sulphates
# - alcohol
# - **quality (Target)** : score between 0 and 10
# - Id

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %% [markdown]
# Разделение на обучающую и тестовую выборки

# %%
df_train, df_val = train_test_split(df, test_size=0.2, random_state=42)

X_train = df_train.drop(['quality', 'Id'], axis=1)
X_val = df_val.drop(['quality', 'Id'], axis=1)

y_train = df_train['quality']
y_val = df_val['quality']

# %% [markdown]
# Задание 4. Примените RabustScaler для стандартизации X_train, X_val

# %%
scaler = RobustScaler()

X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %% [markdown]
# Преобразование значений к тензорам, для дальнейшей работы с pyTorch

# %%
X_train_ts = torch.FloatTensor(X_train)
X_val_ts = torch.FloatTensor(X_val)

y_train_ts = torch.LongTensor(y_train.values)
y_val_ts = torch.LongTensor(y_val.values)

# %%
num_classes = X_train_ts.shape[1]
num_classes
# Out:
# 11

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()

        self.fc1 = nn.Linear(X_train_ts.shape[1], 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 32)
        self.fc4 = nn.Linear(32, 11)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)

        x = self.fc2(x)
        x = self.relu(x)

        x = self.fc3(x)
        x = self.relu(x)

        output = self.fc4(x)
        return output

# %%
model = DNN()

loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# Задание 5. Заполните пропуски функции train_model
#
# 1) Инициализируйте оптимизатор ADAM.
#
# 2) Воспользуйтесь методом zero_grad
#
# 3) Вычислите градиенты функции потерь по параметрам модели, используя метод обратного распространения ошибки. backward
#
# 4) Обновите значения оптимизатора. step

# %%
import torch.optim as optim

def train_model(model, lr=1e-3, n_epoch=500):
    optimizer = optim.Adam(model.parameters(), lr=lr)  # Инициализация оптимизатора Adam

    train_losses = []
    val_losses = []

    train_scores = []
    val_scores = []

    for epoch in range(1, n_epoch+1):
        model.train()
        optimizer.zero_grad()  # Обнуление значений градиентов
        out = model(X_train_ts)
        loss = loss_fn(out, y_train_ts)
        loss.backward()  # Вычисление градиентов функции
        optimizer.step()  # Обновление значений оптимизатора

        acc = (torch.argmax(out, dim=1) == y_train_ts).float().mean().item()

        model.eval()
        with torch.no_grad():
            out_val = model(X_val_ts)
            loss_val = loss_fn(out_val, y_val_ts)
            acc_val = (torch.argmax(out_val, dim=1) == y_val_ts).float().mean().item()

            train_losses.append(loss.item())
            val_losses.append(loss_val.item())

            train_scores.append(acc)
            val_scores.append(acc_val)

        if epoch % 20 == 0:
            print('Epoch : {:3d} / {}, Loss : {:.4f}, Accuracy : {:.2f} %, Val Loss : {:.4f}, Val Accuracy : {:.2f} %'.format(
                epoch, n_epoch, loss.item(), acc*100, loss_val.item(), acc_val*100))

    plt.plot(train_scores)
    plt.plot(val_scores)
    return train_losses, val_losses, train_losses, val_scores

# %%
train_model(model, n_epoch=750);
# Out:
# Epoch :  20 / 750, Loss : 1.8714, Accuracy : 56.56 %, Val Loss : 1.8257, Val Accuracy : 55.46 %
# Epoch :  40 / 750, Loss : 1.2053, Accuracy : 57.66 %, Val Loss : 1.1467, Val Accuracy : 59.83 %
# Epoch :  60 / 750, Loss : 1.0186, Accuracy : 61.05 %, Val Loss : 0.9565, Val Accuracy : 61.14 %
# Epoch :  80 / 750, Loss : 0.9502, Accuracy : 64.33 %, Val Loss : 0.9032, Val Accuracy : 62.01 %
# Epoch : 100 / 750, Loss : 0.9033, Accuracy : 63.46 %, Val Loss : 0.8901, Val Accuracy : 60.26 %
# Epoch : 120 / 750, Loss : 0.8611, Accuracy : 65.97 %, Val Loss : 0.8925, Val Accuracy : 62.45 %
# Epoch : 140 / 750, Loss : 0.8213, Accuracy : 67.51 %, Val Loss : 0.9011, Val Accuracy : 60.70 %
# Epoch : 160 / 750, Loss : 0.7826, Accuracy : 69.91 %, Val Loss : 0.9094, Val Accuracy : 60.70 %
# Epoch : 180 / 750, Loss : 0.7414, Accuracy : 71.23 %, Val Loss : 0.9191, Val Accuracy : 62.01 %
# Epoch : 200 / 750, Loss : 0.6950, Accuracy : 74.40 %, Val Loss : 0.9422, Val Accuracy : 61.57 %
# Epoch : 220 / 750, Loss : 0.6403, Accuracy : 77.13 %, Val Loss : 0.9781, Val Accuracy : 63.76 %
# Epoch : 240 / 750, Loss : 0.5759, Accuracy : 79.65 %, Val Loss : 1.0299, Val Accuracy : 63.32 %
# Epoch : 260 / 750, Loss : 0.5050, Accuracy : 82.28 %, Val Loss : 1.0938, Val Accuracy : 62.45 %
# Epoch : 280 / 750, Loss : 0.4371, Accuracy : 85.34 %, Val Loss : 1.1738, Val Accuracy : 64.63 %
# Epoch : 300 / 750, Loss : 0.3718, Accuracy : 88.62 %, Val Loss : 1.2640, Val Accuracy : 64.19 %
# Epoch : 320 / 750, Loss : 0.3135, Accuracy : 91.79 %, Val Loss : 1.3725, Val Accuracy : 64.63 %
# Epoch : 340 / 750, Loss : 0.2634, Accuracy : 93.54 %, Val Loss : 1.4835, Val Accuracy : 62.01 %
# Epoch : 360 / 750, Loss : 0.2187, Accuracy : 94.64 %, Val Loss : 1.6153, Val Accuracy : 61.57 %
# Epoch : 380 / 750, Loss : 0.1813, Accuracy : 95.62 %, Val Loss : 1.7626, Val Accuracy : 62.01 %
# Epoch : 400 / 750, Loss : 0.1503, Accuracy : 96.50 %, Val Loss : 1.9105, Val Accuracy : 61.57 %
# Epoch : 420 / 750, Loss : 0.1247, Accuracy : 97.16 %, Val Loss : 2.0598, Val Accuracy : 60.26 %
# Epoch : 440 / 750, Loss : 0.1029, Accuracy : 97.92 %, Val Loss : 2.1993, Val Accuracy : 60.70 %
# Epoch : 460 / 750, Loss : 0.0856, Accuracy : 98.47 %, Val Loss : 2.3558, Val Accuracy : 60.26 %
# Epoch : 480 / 750, Loss : 0.0716, Accuracy : 98.80 %, Val Loss : 2.5083, Val Accuracy : 60.26 %
# Epoch : 500 / 750, Loss : 0.0602, Accuracy : 99.02 %, Val Loss : 2.6620, Val Accuracy : 60.26 %
# Epoch : 520 / 750, Loss : 0.0510, Accuracy : 99.23 %, Val Loss : 2.7993, Val Accuracy : 59.83 %
# Epoch : 540 / 750, Loss : 0.0435, Accuracy : 99.34 %, Val Loss : 2.9291, Val Accuracy : 59.39 %
# Epoch : 560 / 750, Loss : 0.0373, Accuracy : 99.56 %, Val Loss : 3.0543, Val Accuracy : 60.26 %
# Epoch : 580 / 750, Loss : 0.0320, Accuracy : 99.56 %, Val Loss : 3.1858, Val Accuracy : 60.26 %
# Epoch : 600 / 750, Loss : 0.0276, Accuracy : 99.56 %, Val Loss : 3.3078, Val Accuracy : 60.26 %
# Epoch : 620 / 750, Loss : 0.0236, Accuracy : 99.56 %, Val Loss : 3.4390, Val Accuracy : 60.26 %
# Epoch : 640 / 750, Loss : 0.0197, Accuracy : 99.67 %, Val Loss : 3.5549, Val Accuracy : 60.70 %
# Epoch : 660 / 750, Loss : 0.0167, Accuracy : 100.00 %, Val Loss : 3.6691, Val Accuracy : 59.83 %
# Epoch : 680 / 750, Loss : 0.0143, Accuracy : 100.00 %, Val Loss : 3.7812, Val Accuracy : 59.83 %
# Epoch : 700 / 750, Loss : 0.0124, Accuracy : 100.00 %, Val Loss : 3.8885, Val Accuracy : 59.83 %
# Epoch : 720 / 750, Loss : 0.0108, Accuracy : 100.00 %, Val Loss : 3.9908, Val Accuracy : 59.83 %
# Epoch : 740 / 750, Loss : 0.0095, Accuracy : 100.00 %, Val Loss : 4.0946, Val Accuracy : 59.83 %

# %% [markdown]
# Можно наблюдать переобучение, так как при росте точности на обучающей выборке, на валидационной ее значение начало снижаться

# %% [markdown]
# Задание 6. Проверьте различные конфигурации (число слоев, их размер) модели DNN.
#
# Можете также опробовать различное число эпох и значения learning_rate при обучении.
#
# Требуется найти такую конфигурацию, при которой переобучения не будет

# %%
# Уменьшим количество слоев и lr, увеличим размер слоев и количество эпох

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()

        self.fc1 = nn.Linear(X_train_ts.shape[1], 32)
        self.fc2 = nn.Linear(32, 11)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)

        output = self.fc2(x)

        return output

# %%
model = DNN()

loss_fn = nn.CrossEntropyLoss()

# %%
import torch.optim as optim

def train_model(model, lr=1e-4, n_epoch=500):
    optimizer = optim.Adam(model.parameters(), lr=lr)  # Инициализация оптимизатора Adam

    train_losses = []
    val_losses = []

    train_scores = []
    val_scores = []

    for epoch in range(1, n_epoch+1):
        model.train()
        optimizer.zero_grad()  # Обнуление значений градиентов
        out = model(X_train_ts)
        loss = loss_fn(out, y_train_ts)
        loss.backward()  # Вычисление градиентов функции
        optimizer.step()  # Обновление значений оптимизатора

        acc = (torch.argmax(out, dim=1) == y_train_ts).float().mean().item()

        model.eval()
        with torch.no_grad():
            out_val = model(X_val_ts)
            loss_val = loss_fn(out_val, y_val_ts)
            acc_val = (torch.argmax(out_val, dim=1) == y_val_ts).float().mean().item()

            train_losses.append(loss.item())
            val_losses.append(loss_val.item())

            train_scores.append(acc)
            val_scores.append(acc_val)

        if epoch % 20 == 0:
            print('Epoch : {:3d} / {}, Loss : {:.4f}, Accuracy : {:.2f} %, Val Loss : {:.4f}, Val Accuracy : {:.2f} %'.format(
                epoch, n_epoch, loss.item(), acc*100, loss_val.item(), acc_val*100))

    plt.plot(train_scores)
    plt.plot(val_scores)
    return train_losses, val_losses, train_losses, val_scores

# %%
train_model(model, n_epoch=2000);
# Out:
# Epoch :  20 / 2000, Loss : 2.4114, Accuracy : 11.82 %, Val Loss : 2.4178, Val Accuracy : 10.92 %
# Epoch :  40 / 2000, Loss : 2.3862, Accuracy : 15.97 %, Val Loss : 2.3900, Val Accuracy : 13.10 %
# Epoch :  60 / 2000, Loss : 2.3614, Accuracy : 19.15 %, Val Loss : 2.3626, Val Accuracy : 16.16 %
# Epoch :  80 / 2000, Loss : 2.3369, Accuracy : 23.30 %, Val Loss : 2.3356, Val Accuracy : 20.09 %
# Epoch : 100 / 2000, Loss : 2.3127, Accuracy : 26.91 %, Val Loss : 2.3088, Val Accuracy : 25.76 %
# Epoch : 120 / 2000, Loss : 2.2886, Accuracy : 30.20 %, Val Loss : 2.2822, Val Accuracy : 30.57 %
# Epoch : 140 / 2000, Loss : 2.2646, Accuracy : 32.49 %, Val Loss : 2.2558, Val Accuracy : 31.88 %
# Epoch : 160 / 2000, Loss : 2.2406, Accuracy : 34.25 %, Val Loss : 2.2294, Val Accuracy : 34.06 %
# Epoch : 180 / 2000, Loss : 2.2166, Accuracy : 36.21 %, Val Loss : 2.2030, Val Accuracy : 36.68 %
# Epoch : 200 / 2000, Loss : 2.1927, Accuracy : 38.18 %, Val Loss : 2.1767, Val Accuracy : 37.55 %
# Epoch : 220 / 2000, Loss : 2.1687, Accuracy : 39.93 %, Val Loss : 2.1505, Val Accuracy : 40.61 %
# Epoch : 240 / 2000, Loss : 2.1446, Accuracy : 40.92 %, Val Loss : 2.1243, Val Accuracy : 42.79 %
# Epoch : 260 / 2000, Loss : 2.1205, Accuracy : 42.67 %, Val Loss : 2.0980, Val Accuracy : 44.54 %
# Epoch : 280 / 2000, Loss : 2.0963, Accuracy : 43.87 %, Val Loss : 2.0717, Val Accuracy : 45.41 %
# Epoch : 300 / 2000, Loss : 2.0721, Accuracy : 45.08 %, Val Loss : 2.0454, Val Accuracy : 46.29 %
# Epoch : 320 / 2000, Loss : 2.0479, Accuracy : 45.95 %, Val Loss : 2.0192, Val Accuracy : 46.29 %
# Epoch : 340 / 2000, Loss : 2.0237, Accuracy : 46.50 %, Val Loss : 1.9932, Val Accuracy : 45.85 %
# Epoch : 360 / 2000, Loss : 1.9996, Accuracy : 46.94 %, Val Loss : 1.9673, Val Accuracy : 46.29 %
# Epoch : 380 / 2000, Loss : 1.9755, Accuracy : 47.16 %, Val Loss : 1.9416, Val Accuracy : 46.29 %
# Epoch : 400 / 2000, Loss : 1.9515, Accuracy : 47.48 %, Val Loss : 1.9161, Val Accuracy : 45.85 %
# Epoch : 420 / 2000, Loss : 1.9276, Accuracy : 47.70 %, Val Loss : 1.8908, Val Accuracy : 45.85 %
# Epoch : 440 / 2000, Loss : 1.9038, Accuracy : 47.92 %, Val Loss : 1.8659, Val Accuracy : 45.85 %
# Epoch : 460 / 2000, Loss : 1.8803, Accuracy : 47.92 %, Val Loss : 1.8412, Val Accuracy : 46.29 %
# Epoch : 480 / 2000, Loss : 1.8569, Accuracy : 47.81 %, Val Loss : 1.8168, Val Accuracy : 45.85 %
# Epoch : 500 / 2000, Loss : 1.8338, Accuracy : 48.14 %, Val Loss : 1.7928, Val Accuracy : 46.29 %
# Epoch : 520 / 2000, Loss : 1.8110, Accuracy : 48.91 %, Val Loss : 1.7692, Val Accuracy : 47.16 %
# Epoch : 540 / 2000, Loss : 1.7885, Accuracy : 49.02 %, Val Loss : 1.7460, Val Accuracy : 47.16 %
# Epoch : 560 / 2000, Loss : 1.7664, Accuracy : 49.12 %, Val Loss : 1.7232, Val Accuracy : 47.60 %
# Epoch : 580 / 2000, Loss : 1.7445, Accuracy : 49.23 %, Val Loss : 1.7009, Val Accuracy : 47.60 %
# Epoch : 600 / 2000, Loss : 1.7231, Accuracy : 49.34 %, Val Loss : 1.6790, Val Accuracy : 48.47 %
# Epoch : 620 / 2000, Loss : 1.7020, Accuracy : 49.89 %, Val Loss : 1.6576, Val Accuracy : 48.47 %
# Epoch : 640 / 2000, Loss : 1.6814, Accuracy : 50.11 %, Val Loss : 1.6366, Val Accuracy : 49.34 %
# Epoch : 660 / 2000, Loss : 1.6612, Accuracy : 50.00 %, Val Loss : 1.6162, Val Accuracy : 48.91 %
# Epoch : 680 / 2000, Loss : 1.6414, Accuracy : 50.00 %, Val Loss : 1.5963, Val Accuracy : 48.47 %
# Epoch : 700 / 2000, Loss : 1.6220, Accuracy : 50.33 %, Val Loss : 1.5768, Val Accuracy : 49.78 %
# Epoch : 720 / 2000, Loss : 1.6031, Accuracy : 50.33 %, Val Loss : 1.5578, Val Accuracy : 49.78 %
# Epoch : 740 / 2000, Loss : 1.5846, Accuracy : 50.33 %, Val Loss : 1.5393, Val Accuracy : 51.09 %
# Epoch : 760 / 2000, Loss : 1.5665, Accuracy : 50.77 %, Val Loss : 1.5213, Val Accuracy : 51.53 %
# Epoch : 780 / 2000, Loss : 1.5489, Accuracy : 51.20 %, Val Loss : 1.5038, Val Accuracy : 51.97 %
# Epoch : 800 / 2000, Loss : 1.5318, Accuracy : 51.97 %, Val Loss : 1.4867, Val Accuracy : 51.09 %
# Epoch : 820 / 2000, Loss : 1.5151, Accuracy : 52.30 %, Val Loss : 1.4701, Val Accuracy : 51.53 %
# Epoch : 840 / 2000, Loss : 1.4989, Accuracy : 52.63 %, Val Loss : 1.4539, Val Accuracy : 51.97 %
# Epoch : 860 / 2000, Loss : 1.4831, Accuracy : 52.84 %, Val Loss : 1.4382, Val Accuracy : 51.97 %
# Epoch : 880 / 2000, Loss : 1.4679, Accuracy : 52.74 %, Val Loss : 1.4230, Val Accuracy : 52.40 %
# Epoch : 900 / 2000, Loss : 1.4530, Accuracy : 53.06 %, Val Loss : 1.4082, Val Accuracy : 52.40 %
# Epoch : 920 / 2000, Loss : 1.4386, Accuracy : 53.17 %, Val Loss : 1.3938, Val Accuracy : 52.40 %
# Epoch : 940 / 2000, Loss : 1.4246, Accuracy : 53.61 %, Val Loss : 1.3798, Val Accuracy : 52.84 %
# Epoch : 960 / 2000, Loss : 1.4109, Accuracy : 53.72 %, Val Loss : 1.3663, Val Accuracy : 53.71 %
# Epoch : 980 / 2000, Loss : 1.3977, Accuracy : 53.94 %, Val Loss : 1.3531, Val Accuracy : 54.15 %
# Epoch : 1000 / 2000, Loss : 1.3848, Accuracy : 53.94 %, Val Loss : 1.3403, Val Accuracy : 55.90 %
# Epoch : 1020 / 2000, Loss : 1.3724, Accuracy : 54.27 %, Val Loss : 1.3279, Val Accuracy : 55.46 %
# Epoch : 1040 / 2000, Loss : 1.3602, Accuracy : 54.16 %, Val Loss : 1.3159, Val Accuracy : 55.46 %
# Epoch : 1060 / 2000, Loss : 1.3485, Accuracy : 54.49 %, Val Loss : 1.3042, Val Accuracy : 55.46 %
# Epoch : 1080 / 2000, Loss : 1.3371, Accuracy : 54.92 %, Val Loss : 1.2929, Val Accuracy : 55.46 %
# Epoch : 1100 / 2000, Loss : 1.3261, Accuracy : 54.92 %, Val Loss : 1.2819, Val Accuracy : 55.46 %
# Epoch : 1120 / 2000, Loss : 1.3155, Accuracy : 55.14 %, Val Loss : 1.2714, Val Accuracy : 55.02 %
# Epoch : 1140 / 2000, Loss : 1.3052, Accuracy : 55.36 %, Val Loss : 1.2611, Val Accuracy : 55.90 %
# Epoch : 1160 / 2000, Loss : 1.2952, Accuracy : 54.92 %, Val Loss : 1.2511, Val Accuracy : 56.33 %
# Epoch : 1180 / 2000, Loss : 1.2855, Accuracy : 54.81 %, Val Loss : 1.2414, Val Accuracy : 56.77 %
# Epoch : 1200 / 2000, Loss : 1.2762, Accuracy : 54.81 %, Val Loss : 1.2320, Val Accuracy : 57.21 %
# Epoch : 1220 / 2000, Loss : 1.2671, Accuracy : 55.14 %, Val Loss : 1.2229, Val Accuracy : 57.64 %
# Epoch : 1240 / 2000, Loss : 1.2583, Accuracy : 55.25 %, Val Loss : 1.2141, Val Accuracy : 57.21 %
# Epoch : 1260 / 2000, Loss : 1.2498, Accuracy : 55.80 %, Val Loss : 1.2056, Val Accuracy : 56.77 %
# Epoch : 1280 / 2000, Loss : 1.2416, Accuracy : 56.13 %, Val Loss : 1.1973, Val Accuracy : 56.77 %
# Epoch : 1300 / 2000, Loss : 1.2337, Accuracy : 56.78 %, Val Loss : 1.1893, Val Accuracy : 57.21 %
# Epoch : 1320 / 2000, Loss : 1.2260, Accuracy : 57.22 %, Val Loss : 1.1815, Val Accuracy : 58.08 %
# Epoch : 1340 / 2000, Loss : 1.2185, Accuracy : 57.33 %, Val Loss : 1.1740, Val Accuracy : 58.08 %
# Epoch : 1360 / 2000, Loss : 1.2113, Accuracy : 57.55 %, Val Loss : 1.1667, Val Accuracy : 58.95 %
# Epoch : 1380 / 2000, Loss : 1.2043, Accuracy : 57.55 %, Val Loss : 1.1595, Val Accuracy : 58.95 %
# Epoch : 1400 / 2000, Loss : 1.1976, Accuracy : 57.99 %, Val Loss : 1.1527, Val Accuracy : 59.39 %
# Epoch : 1420 / 2000, Loss : 1.1910, Accuracy : 58.42 %, Val Loss : 1.1460, Val Accuracy : 58.95 %
# Epoch : 1440 / 2000, Loss : 1.1847, Accuracy : 58.86 %, Val Loss : 1.1396, Val Accuracy : 58.95 %
# Epoch : 1460 / 2000, Loss : 1.1786, Accuracy : 58.97 %, Val Loss : 1.1335, Val Accuracy : 58.95 %
# Epoch : 1480 / 2000, Loss : 1.1727, Accuracy : 58.86 %, Val Loss : 1.1275, Val Accuracy : 58.95 %
# Epoch : 1500 / 2000, Loss : 1.1669, Accuracy : 59.08 %, Val Loss : 1.1218, Val Accuracy : 59.39 %
# Epoch : 1520 / 2000, Loss : 1.1614, Accuracy : 59.08 %, Val Loss : 1.1162, Val Accuracy : 59.83 %
# Epoch : 1540 / 2000, Loss : 1.1560, Accuracy : 59.19 %, Val Loss : 1.1109, Val Accuracy : 60.26 %
# Epoch : 1560 / 2000, Loss : 1.1508, Accuracy : 59.08 %, Val Loss : 1.1057, Val Accuracy : 60.26 %
# Epoch : 1580 / 2000, Loss : 1.1457, Accuracy : 59.08 %, Val Loss : 1.1006, Val Accuracy : 60.26 %
# Epoch : 1600 / 2000, Loss : 1.1408, Accuracy : 58.97 %, Val Loss : 1.0957, Val Accuracy : 60.26 %
# Epoch : 1620 / 2000, Loss : 1.1360, Accuracy : 58.86 %, Val Loss : 1.0910, Val Accuracy : 59.83 %
# Epoch : 1640 / 2000, Loss : 1.1314, Accuracy : 59.08 %, Val Loss : 1.0864, Val Accuracy : 60.26 %
# Epoch : 1660 / 2000, Loss : 1.1269, Accuracy : 59.30 %, Val Loss : 1.0819, Val Accuracy : 60.70 %
# Epoch : 1680 / 2000, Loss : 1.1225, Accuracy : 59.30 %, Val Loss : 1.0776, Val Accuracy : 59.83 %
# Epoch : 1700 / 2000, Loss : 1.1182, Accuracy : 59.41 %, Val Loss : 1.0734, Val Accuracy : 60.26 %
# Epoch : 1720 / 2000, Loss : 1.1140, Accuracy : 59.41 %, Val Loss : 1.0694, Val Accuracy : 60.26 %
# Epoch : 1740 / 2000, Loss : 1.1100, Accuracy : 59.30 %, Val Loss : 1.0655, Val Accuracy : 59.83 %
# Epoch : 1760 / 2000, Loss : 1.1060, Accuracy : 59.08 %, Val Loss : 1.0617, Val Accuracy : 59.83 %
# Epoch : 1780 / 2000, Loss : 1.1022, Accuracy : 59.08 %, Val Loss : 1.0580, Val Accuracy : 59.83 %
# Epoch : 1800 / 2000, Loss : 1.0984, Accuracy : 59.19 %, Val Loss : 1.0544, Val Accuracy : 59.83 %
# Epoch : 1820 / 2000, Loss : 1.0948, Accuracy : 59.41 %, Val Loss : 1.0509, Val Accuracy : 59.83 %
# Epoch : 1840 / 2000, Loss : 1.0912, Accuracy : 59.52 %, Val Loss : 1.0475, Val Accuracy : 59.83 %
# Epoch : 1860 / 2000, Loss : 1.0877, Accuracy : 59.63 %, Val Loss : 1.0442, Val Accuracy : 60.26 %
# Epoch : 1880 / 2000, Loss : 1.0843, Accuracy : 59.74 %, Val Loss : 1.0410, Val Accuracy : 59.83 %
# Epoch : 1900 / 2000, Loss : 1.0810, Accuracy : 59.85 %, Val Loss : 1.0378, Val Accuracy : 59.83 %
# Epoch : 1920 / 2000, Loss : 1.0777, Accuracy : 59.85 %, Val Loss : 1.0348, Val Accuracy : 60.26 %
# Epoch : 1940 / 2000, Loss : 1.0745, Accuracy : 59.85 %, Val Loss : 1.0319, Val Accuracy : 60.26 %
# Epoch : 1960 / 2000, Loss : 1.0714, Accuracy : 59.96 %, Val Loss : 1.0290, Val Accuracy : 59.83 %
# Epoch : 1980 / 2000, Loss : 1.0684, Accuracy : 59.96 %, Val Loss : 1.0263, Val Accuracy : 60.26 %
# Epoch : 2000 / 2000, Loss : 1.0654, Accuracy : 59.85 %, Val Loss : 1.0236, Val Accuracy : 60.26 %
